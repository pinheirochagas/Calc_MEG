# %%
# Function to decode operation

# %%
# %pylab inline 

import mne
from mne.datasets import spm_face
from mne.decoding import GeneralizationAcrossTime
import sys
import os.path as op
import numpy as np
import matplotlib.pyplot as plt
import scipy.io as sio
import pandas as pd
from scipy import stats
#Add personal functions to python path
sys.path.append('/neurospin/meg/meg_tmp/Calculation_Pedro_2014/scripts/decoding/')
#sys.path.append('/Volumes/NeuroSpin2T/Calculation_Pedro_2014/scripts/decoding/')
from fldtrp2mne import fldtrp2mne
from calc_twoClassClassify import calc_twoClassClassify
from sklearn import svm
from sklearn.cross_validation import cross_val_score, StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.pipeline import make_pipeline
from sklearn.cross_validation import StratifiedKFold
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['diagonal', 'info']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
# Out:
# <function fldtrp2mne.fldtrp2mne>

# %%
#Directories
data_path = '/neurospin/meg/meg_tmp/Calculation_Pedro_2014/data/mat/'
result_path = '/neurospin/meg/meg_tmp/Calculation_Pedro_2014/data/decoding/'
#data_path = '/Volumes/NeuroSpin2T/Calculation_Pedro_2014/data/mat/'
#result_path = '/Volumes/NeuroSpin2T/Calculation_Pedro_2014/data/decoding/'

#Subjects
subjects = ['s01', 's02', 's03', 's04', 's05', 's06', 's07', 's08', 's09', 's10', 
            's11', 's12', 's13', 's14', 's15', 's16', 's17', 's18','s19', 's21', 's22']

    
#subjects = ['s11']

#subjects = ['s01']


#General parameters
baseline = (-0.5, -0.05)
downsmpDec = 4

#Decoding
trainset = 'addsub'
testset = 'addsub'
decCond = ['1', '2', '3', '4']

params = {'baseline': baseline, 'downsmpDec': downsmpDec, 
'Classification': decCond, 'trainset': trainset, 'testset': testset}

#Results initialization
all_scores = []
all_diagonals = []

# %%
for sub in subjects:
    fname = op.join(data_path, sub + '_calc.mat') 
    epoch = fldtrp2mne(fname, 'data')

    #Baseline-correct & filter data
    print('Baseline-correcting data for subject: ' + sub)
    epoch.apply_baseline(baseline)
    
    #Load condition/behavior info
    matfile = sio.loadmat(fname)
    print('Loading trialinfo for subject: ' + sub)   
    trialinfo = matfile['data']['trialinfo']   
    
    run = trialinfo[0][0][0][0][0].T
    operand1 = trialinfo[0][0][0][0][1].T
    operator = trialinfo[0][0][0][0][2].T
    operand2 = trialinfo[0][0][0][0][3].T
    preResult = trialinfo[0][0][0][0][4].T
    delay = trialinfo[0][0][0][0][5].T
    corrResult = trialinfo[0][0][0][0][6].T
    deviant = trialinfo[0][0][0][0][7].T
    absdeviant = trialinfo[0][0][0][0][8].T
    rt = trialinfo[0][0][0][0][9].T
    respSide = trialinfo[0][0][0][0][10].T

    
    # Merge back and define conditions
    info = pd.DataFrame(data = np.concatenate((run, operand1, operator, operand2, preResult, delay, corrResult, deviant, absdeviant, rt, respSide), axis = 1), 
                        columns = ['run', 'operand1', 'operator', 'operand2', 'preResult', 'delay', 'corrResult', 'deviant', 'absdeviant', 'rt', 'respSide'])

    #info['absdeviant'][info['absdeviant'] != 0] = 1
    epochsDeviant = (info['absdeviant'] > 0) & (info['operator'] != 0)
    

    # Decoding
    epochs = epoch[epochsDeviant] #select only target-present trials
    info = info[epochsDeviant]    #
    y = np.array(info['absdeviant']) #select labels for the conditions
    y = y.astype(numpy.float64)
    # Downsampling for decoding
    epochs.decimate(downsmpDec)
    

    print('Decoding subject: ' + sub)
    gat, score, diagonal = calc_twoClassClassify(epochs, y, [], [], params)
    gat.plot()
    gat.plot_diagonal()  # plot decoding across time (correspond to GAT diagonal)

    #Store scores of different subjects in the same list
    all_scores.append(score)
    all_diagonals.append(diagonal)
    
#Transform into a numpy array   
all_scores = np.array(all_scores)
all_diagonals = np.array(all_diagonals)

# Save individual results
fname = op.join(result_path, 'Classification_deviant ' + decCond[0] + '_vs_' + 
                decCond[1] + '_vs_' + decCond[2] + '_vs_' + decCond[3] + '_Trainset_' + trainset + '_Testset_' + testset) 
np.save(fname, all_scores)

# Compute group averages
group_scores = np.mean(all_scores, 0)
sem_group_scores = stats.sem(all_scores, 0)

group_diagonal = np.mean(all_diagonals, 0)
sem_group_diagonal = stats.sem(all_diagonals, 0)
# Out:
# Baseline-correcting data for subject: s01
# Applying baseline correction ... (mode: mean)
# Loading trialinfo for subject: s01
# Decoding subject: s01
# /volatile/anaconda/lib/python2.7/site-packages/mne/epochs.py:394: UserWarning: The measurement information indicates a low-pass frequency of 125 Hz. The decim=4 parameter will result in a sampling frequency of 62.5 Hz, which can cause aliasing artifacts.
#   % (lowpass, decim, new_sfreq))  # > 50% nyquist limit
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    7.7s finished
# [Parallel(n_jobs=8)]: Done   1 out of   1 | elapsed: 11.5min finished
# [Parallel(n_jobs=8)]: Done   8 out of   8 | elapsed:    9.9s finished
# Baseline-correcting data for subject: s02
# Applying baseline correction ... (mode: mean)
# Loading trialinfo for subject: s02
# Decoding subject: s02
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-14-6b603e1c1540> in <module>()
#      43
#      44     print('Decoding subject: ' + sub)
# ---> 45     gat, score, diagonal = calc_twoClassClassify(epochs, y, [], [], params)
#      46     gat.plot()
#      47     gat.plot_diagonal()  # plot decoding across time (correspond to GAT diagonal)
#
# /neurospin/meg/meg_tmp/Calculation_Pedro_2014/scripts/decoding/calc_twoClassClassify.pyc in calc_twoClassClassify(X_train, y_train, X_test, y_test, params)
#      40     ###Learning process###
#      41     gat = GeneralizationAcrossTime(clf = clf, cv = cv, n_jobs = -1)
# ---> 42     gat.fit(X_train, y = y_train)
#      43     score = gat.score(X_train, y = y_train)
#      44
#
# /volatile/anaconda/lib/python2.7/site-packages/mne/decoding/time_gen.pyc in fit(self, epochs, y)
#     165                                   X[..., f(train_slices_chunk)],
#     166                                   y, train_slices_chunk, cv)
# --> 167                        for train_slices_chunk in splits)
#     168         # Unpack estimators into time slices X folds list of lists.
#     169         self.estimators_ = sum(out, list())
#
# /volatile/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     769         self._aborting = False
#     770         if not self._managed_pool:
# --> 771             n_jobs = self._initialize_pool()
#     772         else:
#     773             n_jobs = self._effective_n_jobs()
#
# /volatile/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in _initialize_pool(self)
#     539                     # Use Python 3.4+ multiprocessing context isolation
#     540                     poolargs['context'] = self._mp_context
# --> 541                 self._pool = MemmapingPool(n_jobs, **poolargs)
#     542
#     543                 # We are using multiprocessing, we also want to capture
#
# /volatile/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/pool.pyc in __init__(self, processes, temp_folder, max_nbytes, mmap_mode, forward_reducers, backward_reducers, verbose, context_id, prewarm, **kwargs)
#     578             backward_reducers=backward_reducers)
#     579         poolargs.update(kwargs)
# --> 580         super(MemmapingPool, self).__init__(**poolargs)
#     581
#     582     def terminate(self):
#
# /volatile/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/pool.pyc in __init__(self, processes, forward_reducers, backward_reducers, **kwargs)
#     417         poolargs = dict(processes=processes)
#     418         poolargs.update(kwargs)
# --> 419         super(PicklingPool, self).__init__(**poolargs)
#     420
#     421     def _setup_queues(self):
#
# /volatile/anaconda/lib/python2.7/multiprocessing/pool.pyc in __init__(self, processes, initializer, initargs, maxtasksperchild)
#     157         self._processes = processes
#     158         self._pool = []
# --> 159         self._repopulate_pool()
#     160
#     161         self._worker_handler = threading.Thread(
#
# /volatile/anaconda/lib/python2.7/multiprocessing/pool.pyc in _repopulate_pool(self)
#     221             w.name = w.name.replace('Process', 'PoolWorker')
#     222             w.daemon = True
# --> 223             w.start()
#     224             debug('added worker')
#     225
#
# /volatile/anaconda/lib/python2.7/multiprocessing/process.pyc in start(self)
#     128         else:
#     129             from .forking import Popen
# --> 130         self._popen = Popen(self)
#     131         _current_process._children.add(self)
#     132
#
# /volatile/anaconda/lib/python2.7/multiprocessing/forking.pyc in __init__(self, process_obj)
#     119             self.returncode = None
#     120
# --> 121             self.pid = os.fork()
#     122             if self.pid == 0:
#     123                 if 'random' in sys.modules:
#
# OSError: [Errno 12] Cannot allocate memory

# %%
info['operator']
# Out:
# 3     -1
# 4      1
# 7      1
# 8     -1
# 10     1
# 12    -1
# 13     1
# 14     1
# 15    -1
# 17    -1
# 18    -1
# 21     1
# 23     1
# 25    -1
# 32     1
# 34     1
# 35    -1
# 36    -1
# 39    -1
# 40     1
# 42    -1
# 43    -1
# 44    -1
# 45    -1
# 51    -1
# 55     1
# 56     1
# 57    -1
# 58     1
# 62     1
#       ..
# 319    1
# 323   -1
# 330    1
# 331    1
# 334   -1
# 338   -1
# 341    1
# 344   -1
# 345    1
# 351    1
# 357   -1
# 358   -1
# 359   -1
# 360   -1
# 361   -1
# 362    1
# 363   -1
# 370   -1
# 371    1
# 372    1
# 373   -1
# 375    1
# 381    1
# 382   -1
# 384    1
# 385    1
# 387   -1
# 389    1
# 396   -1
# 401    1
# Name: operator, dtype: int32

# %%
# Plotting  

# Plot GAT
plt.imshow(group_scores, origin = 'lower', extent = [epochs.times[0], epochs.times[len(epochs.times)-1], 
                                                     epochs.times[0], epochs.times[len(epochs.times)-1]]) #flip the matrix around
plt.axvline(0, color = 'k') #mark stimulus onset
plt.axhline(0, color = 'k') #mark stimulus onset
plt.colorbar()
plt.xlabel('Testing Time (s)')
plt.ylabel('Training Time (s)')
plt.title('Group average generalization across time \n Classification: ' + decCond[0] + ' vs ' 
+ decCond[1] + '\n Trainset: ' + trainset + ', Testset: ' + testset)

# %%
# Plot Diagonal
plt.plot(epochs.times, group_diagonal, label = "Classification score")
plt.axvline(0, color = 'k') #mark stimulus onset
plt.axhline(0.25, color = 'k', ls = '--', label = "Chance") #mark chance level
plt.legend(loc = 'upper right')
plt.xlabel('Time (s)')
plt.ylabel('Classification Score (%)')
plt.title('Cl assification: ' + decCond[0] + ' vs ' 
+ decCond[1] + '\n Trainset: ' + trainset + ', Testset: ' + testset)

# %%
size(y)
# Out:
# 287

# %%
info
# Out:
#      operation  operand1  operand2  absdeviant  corrResult
# 0           -1         3         0           4           3
# 1            0         3        33           3           3
# 2            1         4         1           1           5
# 5           -1         3         0           4           3
# 6            0         3        33           3           3
# 7            0         4        33           3           4
# 8           -1         5         1           0           4
# 10          -1         6         3           1           3
# 11           1         4         0           4           4
# 13          -1         5         2           3           3
# 14           0         6        33           0           6
# 15          -1         4         1           0           3
# 16           1         3         3           0           6
# 17           1         4         2           0           6
# 18           0         3        33           0           3
# 20           1         4         1           1           5
# 21          -1         6         2           0           4
# 22           1         3         2           3           5
# 23           1         3         0           4           3
# 25           0         6        33           4           6
# 26           1         5         0           4           5
# 28           0         5        33           0           5
# 29           1         5         1           0           6
# 30          -1         6         1           0           5
# 32           0         5        33           1           5
# 34          -1         6         0           0           6
# 36           1         3         1           0           4
# 37          -1         4         0           0           4
# 38           0         4        33           0           4
# 40           1         6         0           2           6
# ..         ...       ...       ...         ...         ...
# 367          1         3         3           0           6
# 368          0         5        33           4           5
# 369          1         5         1           0           6
# 372          1         3         2           0           5
# 373         -1         6         1           4           5
# 374          1         6         0           2           6
# 375          0         6        33           0           6
# 376         -1         6         3           3           3
# 377          0         3        33           0           3
# 379          0         5        33           4           5
# 380          1         3         3           0           6
# 381         -1         5         0           0           5
# 382          1         5         0           0           5
# 384          0         4        33           2           4
# 386          1         3         1           0           4
# 388          1         4         2           2           6
# 389         -1         4         1           2           3
# 390         -1         6         0           4           6
# 391         -1         6         2           2           4
# 395          1         4         0           3           4
# 396         -1         3         0           0           3
# 397          0         5        33           2           5
# 399          0         6        33           0           6
# 400          1         3         0           0           3
# 401         -1         5         2           1           3
# 403          0         4        33           4           4
# 404          0         3        33           0           3
# 406         -1         5         1           0           4
# 407          1         4         1           0           5
# 408         -1         4         0           0           4
#
# [287 rows x 5 columns]
